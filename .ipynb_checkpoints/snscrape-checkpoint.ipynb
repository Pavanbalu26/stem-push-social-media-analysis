# %%
from snscrape.modules.twitter import TwitterSearchScraper
import pandas as pd

query = "STEM EDUCATION"
tweets = []
limit = 500
for tweet in TwitterSearchScraper(query).get_items():
    if len(tweets) == limit:
        break
    else:
            tweets.append([tweet.date,tweet.user.username,tweet.rawContent])
df = pd.DataFrame(tweets,columns = ['Date','username','content'])
df
# Out:
#                          Date         username  \
# 0   2023-04-17 07:35:56+00:00     block_hakase
# 1   2023-04-17 07:35:23+00:00           nsbeap
# 2   2023-04-17 07:27:00+00:00         ciecyork
# 3   2023-04-17 07:25:59+00:00    TheGiftsDepot
# 4   2023-04-17 07:12:32+00:00  Home__Education
# ..                        ...              ...
# 495 2023-04-14 22:33:00+00:00         MTSUNews
# 496 2023-04-14 22:32:22+00:00  nerdygangstainc
# 497 2023-04-14 22:27:59+00:00   InnovationSCLA
# 498 2023-04-14 22:18:01+00:00      iamangelfdn
# 499 2023-04-14 22:16:20+00:00     UCDEducation
#
#                                                content
# 0    第42期こども研究員募集!!\n5月より「ロボットとみらい研究会」の新しい期が始まります\n...
# 1    We are forever grateful for this amazing exper...
# 2    Children from Harrowgate primary during their ...
# 3    USA STORE ONLY:\n\nHasbro Gaming: Jenga Classi...
# 4    Discounts for Education Resources\nMaths, Engl...
# ..                                                 ...
# 495  #MTSU is feeling energetic about its new #Quan...
# 496  Thank you to the Marion Law Academy family, Pr...
# 497  Hey everyone, \nThe STEM Night &amp; Design Gu...
# 498  #Learn how ocean currents work 🌊\n\n🎥: @scienc...
# 499  At 2:50pm, @DrAPW15 shares “Building Bold, Bra...
#
# [500 rows x 3 columns]
